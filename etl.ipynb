# %%
import pandas as pd
from IPython.display import display

# %%
column_names = ["NUMERO_DE_RASTREO", "TIPO_DE_IDENTIFICACION_DEL_TITULAR", "NRO_DE_IDENTIFICACION_DEL_TITULAR", "INDICADOR_DE_SOLO_TITULAR_PRINCIPAL", "INDICADOR_DE_OMITIR_CUENTAS_CANCELADAS",
"OFICINA_DUENA_DE_LA_CUENTA", "CUENTA_PERMITE_DEBITOS_SOBREGIRO", "CUENTA_PERMITE_CREDITOS_SOBREGIRO", "MARCAS_DE_LAS_CUENTAS", "FILLER_PARA_USO_FUTURO", "CODIGO_DE_RESPUESTA","DESCRIPCION_DE_RESPUESTA",
"CONSECUTIVO_DE_CUENTAS_CONSULTADAS_POR_CLIENTE","TIPO_DE_CUENTA_A_CONSULTAR", "NUMERO_DE_CUENTA","CODIGO_DE_LA_OFICINA_DUENA_DE_LA_CUENTA", "CUENTA_PERMITE_DEBITOS", "CUENTA_PERMITE_CREDITOS", "MONEDA", 
"FECHA_DE_APERTURA_DE_LA_CUENTA", "NUMERO_DE_DIAS_DE_INACTIVIDAD_DE_LA_CUENTA", "INDICADOR_DE_CUENTA_CANCELADA", "FECHA_DE_CIERRE_DE_LA_CUENTA","NUMERO_DE_COTITULARES", "TIPO_IDENTIFICACION_TITULAR", "NRO_DE_IDENTIFICACION_TITULAR",
"NOMBRE_TITULAR_CUENTA", "RELACION_ENTRE_CLIENTE_Y_CUENTA", "REGIMEN_CUENTA_MAESTRA", "CODIGO_DE_SERVICIO","PLAZO_SOBREGIRO", "DIAS_SOBREGIRO",
"DIAS_EN_MORA_SOBREGIRO", "CLASIFICACION_CARTERA_PARA_CTAS_CORRIENTES", "SIGNO_DEL_CUPO_DE_SOBREGIRO", "VALOR_DEL_CUPO_DE_SOBREGIRO", "SIGNO_DEL_SALDO_EFECTIVO_DE_LA_CUENTA",
"SALDO_EFECTIVO_DE_LA_CUENTA", "SIGNO_DEL_SALDO_EN_CANJE_DE_LA_CUENTA", "SALDO_EN_CANJE_DE_LA_CUENTA",
"SIGNO_DEL_SALDO_DISPONIBLE_DE_LA_CUENTA", "SALDO_DISPONIBLE_DE_LA_CUENTA", "SIGNO_DEL_SALDO_DISPONIBLE_SIN_SOBREGIRO", "SALDO_DISPONIBLE_SIN_SOBREGIRO", "SIGNO_DEL_SALDO_EN_CUENTA_POR_COBRAR",
"SALDO_EN_CUENTA_POR_COBRAR", "SIGNO_DEL_SALDO_BLOQUEADO", "SALDO_BLOQUEADO", "SIGNO_DE_SALDO_EN_BOLSILLOS", "SALDO_EN_BOLSILLOS", "SIGNO_DEL_SALDO_EN_CANJE_AL_INICIO_DEL_DIA", "SALDO_EN_CANJE_AL_INICIO_DEL_DIA",
"SIGNO_DEL_SALDO_EFECTIVO_AL_INICIO_DEL_DIA", "SALDO_EFECTIVO_AL_INICIO_DEL_DIA", "SIGNO_DEL_SALDO_DE_DISPONIBLE_DEL_CUPO_DE_SOBREGIRO", "SALDO_DE_DISPONIBLE_DEL_CUPO_DE_SOBREGIRO",
"SIGNO_INTERES_NORMALES", "INTERES_NORMALES", " SIGNO_INTERES_EN_SUSPENSION", "INTERES_EN_SUSPENSION", "SIGNO_CUPO_DE_REMESAS", "CUPO_DE_REMESAS", "SIGNO_CUPO_REMESA_NEGOCIADA", "CUPO_REMESA_NEGOCIADA",
"SIGNO_UTILIZACION_REMESAS", "UTILIZACION_REMESAS", "UTILIZACION_DE_REMESAS", "PARA_USO_FUTURO_INFO_DE_LA_CUENTA", "CAPTACION"
]

print(len(column_names))

types = {}

for value in column_names:
    types[value] = str

df_productos_legales = pd.read_csv("data/input/ProductosLegales", sep="|", header=None, names=column_names, index_col=False, dtype=types)
display(df_productos_legales)
# Out:
# 69
#       NUMERO_DE_RASTREO TIPO_DE_IDENTIFICACION_DEL_TITULAR  \
# 0          000000000001                                  1
# 1          000000000021                                  1
# 2          000000000002                                  1
# 3          000000000040                                  1
# 4          000000000023                                  1
# ...                 ...                                ...
# 33277      000000009025                                  1
# 33278      000000009029                                  1
# 33279      000000009030                                  1
# 33280      000000009030                                  1
# 33281      000000009030                                  1
#
#       NRO_DE_IDENTIFICACION_DEL_TITULAR INDICADOR_DE_SOLO_TITULAR_PRINCIPAL  \
# 0                       000000068287066                                   T
# 1                       000000008699669                                   T
# ...

# %%
df_productos_legales.describe()
# Out:
#        NUMERO_DE_RASTREO TIPO_DE_IDENTIFICACION_DEL_TITULAR  \
# count              33282                              33282
# unique              7879                                  2
# top         000000008376                                  3
# freq                 921                              24729
#
#        NRO_DE_IDENTIFICACION_DEL_TITULAR INDICADOR_DE_SOLO_TITULAR_PRINCIPAL  \
# count                              33282                               33282
# unique                              6240                                   1
# top                      000000890903938                                   T
# freq                               22104                               33282
#
#        INDICADOR_DE_OMITIR_CUENTAS_CANCELADAS OFICINA_DUENA_DE_LA_CUENTA  \
# count                                   33282                          0
# unique                                      1                          0
# ...

# %%
df_productos_legales.shape
# Out:
# (33282, 69)

# %%
total_null = df_productos_legales.isnull().sum().sort_values(ascending = False) # Total de nulos
percent_null = (df_productos_legales.isnull().sum()/df_productos_legales.isnull().count()).sort_values(ascending = False) #porcentaje de nulos
missing_data = pd.concat([total_null,percent_null],axis = 1,keys=['total_null','percent_null'])
missing_data
# Out:
#                                             total_null  percent_null
# OFICINA_DUENA_DE_LA_CUENTA                       33282           1.0
# CUENTA_PERMITE_DEBITOS_SOBREGIRO                 33282           1.0
# CUENTA_PERMITE_CREDITOS_SOBREGIRO                33282           1.0
# MARCAS_DE_LAS_CUENTAS                            33282           1.0
# FILLER_PARA_USO_FUTURO                           33282           1.0
# ...                                                ...           ...
# DIAS_EN_MORA_SOBREGIRO                               0           0.0
# CLASIFICACION_CARTERA_PARA_CTAS_CORRIENTES           0           0.0
# TIPO_DE_IDENTIFICACION_DEL_TITULAR                   0           0.0
# VALOR_DEL_CUPO_DE_SOBREGIRO                          0           0.0
# CAPTACION                                            0           0.0
#
# [69 rows x 2 columns]

# %%
df_productos_legales.dtypes
# Out:
# NUMERO_DE_RASTREO                         object
# TIPO_DE_IDENTIFICACION_DEL_TITULAR        object
# NRO_DE_IDENTIFICACION_DEL_TITULAR         object
# INDICADOR_DE_SOLO_TITULAR_PRINCIPAL       object
# INDICADOR_DE_OMITIR_CUENTAS_CANCELADAS    object
#                                            ...
# SIGNO_UTILIZACION_REMESAS                 object
# UTILIZACION_REMESAS                       object
# UTILIZACION_DE_REMESAS                    object
# PARA_USO_FUTURO_INFO_DE_LA_CUENTA         object
# CAPTACION                                 object
# Length: 69, dtype: object

# %%
df_productos_virtuales = pd.read_csv("data/input/ProductosVirtuales", sep="|", header=None, names=column_names, dtype=types)
df_productos_virtuales.head()
# Out:
#   NUMERO_DE_RASTREO TIPO_DE_IDENTIFICACION_DEL_TITULAR  \
# 0      000000000001                                  3
# 1      000000000307                                  2
# 2      000000000307                                  3
# 3      000000000205                                  7
# 4      000000000069                                  5
#
#   NRO_DE_IDENTIFICACION_DEL_TITULAR INDICADOR_DE_SOLO_TITULAR_PRINCIPAL  \
# 0                         890900250                                   T
# 1                          59152459                                   T
# 2                    19091109214037                                   T
# 3                         219030612                                   T
# 4                        5059152464                                   T
#
#   INDICADOR_DE_OMITIR_CUENTAS_CANCELADAS OFICINA_DUENA_DE_LA_CUENTA  \
# 0                                      Y                        NaN
# ...

# %%
total_null = df_productos_virtuales.isnull().sum().sort_values(ascending = False) # Total de nulos
percent_null = (df_productos_virtuales.isnull().sum()/df_productos_virtuales.isnull().count()).sort_values(ascending = False) #porcentaje de nulos
missing_data = pd.concat([total_null,percent_null],axis = 1,keys=['total_null','percent_null'])
missing_data
# Out:
#                                             total_null  percent_null
# OFICINA_DUENA_DE_LA_CUENTA                         928           1.0
# CUENTA_PERMITE_DEBITOS_SOBREGIRO                   928           1.0
# CUENTA_PERMITE_CREDITOS_SOBREGIRO                  928           1.0
# MARCAS_DE_LAS_CUENTAS                              928           1.0
# FILLER_PARA_USO_FUTURO                             928           1.0
# ...                                                ...           ...
# DIAS_EN_MORA_SOBREGIRO                               0           0.0
# CLASIFICACION_CARTERA_PARA_CTAS_CORRIENTES           0           0.0
# TIPO_DE_IDENTIFICACION_DEL_TITULAR                   0           0.0
# VALOR_DEL_CUPO_DE_SOBREGIRO                          0           0.0
# CAPTACION                                            0           0.0
#
# [69 rows x 2 columns]

# %%
df_productos_virtuales.dtypes
# Out:
# NUMERO_DE_RASTREO                         object
# TIPO_DE_IDENTIFICACION_DEL_TITULAR        object
# NRO_DE_IDENTIFICACION_DEL_TITULAR         object
# INDICADOR_DE_SOLO_TITULAR_PRINCIPAL       object
# INDICADOR_DE_OMITIR_CUENTAS_CANCELADAS    object
#                                            ...
# SIGNO_UTILIZACION_REMESAS                 object
# UTILIZACION_REMESAS                       object
# UTILIZACION_DE_REMESAS                    object
# PARA_USO_FUTURO_INFO_DE_LA_CUENTA         object
# CAPTACION                                 object
# Length: 69, dtype: object

# %%
df_productos_legales.describe()
# Out:
#        NUMERO_DE_RASTREO TIPO_DE_IDENTIFICACION_DEL_TITULAR  \
# count              33282                              33282
# unique              7879                                  2
# top         000000008376                                  3
# freq                 921                              24729
#
#        NRO_DE_IDENTIFICACION_DEL_TITULAR INDICADOR_DE_SOLO_TITULAR_PRINCIPAL  \
# count                              33282                               33282
# unique                              6240                                   1
# top                      000000890903938                                   T
# freq                               22104                               33282
#
#        INDICADOR_DE_OMITIR_CUENTAS_CANCELADAS OFICINA_DUENA_DE_LA_CUENTA  \
# count                                   33282                          0
# unique                                      1                          0
# ...

# %%
df_productos = df_productos_legales.append(df_productos_virtuales)
# Out:
# /var/folders/sc/_jqd0m8s5f9gqbgm5k_1twjc0000gn/T/ipykernel_78686/4251618290.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_productos = df_productos_legales.append(df_productos_virtuales)

# %%
df_productos.shape
# Out:
# (34210, 69)

# %%
df_productos.sort_values(by=['NRO_DE_IDENTIFICACION_DEL_TITULAR'])
# Out:
#       NUMERO_DE_RASTREO TIPO_DE_IDENTIFICACION_DEL_TITULAR  \
# 856        000000000218                                  1
# 857        000000000218                                  1
# 12114      000000013973                                  1
# 13899      000000012040                                  1
# 22047      000000013266                                  1
# ...                 ...                                ...
# 0          000000000001                                  3
# 870        000000000009                                  3
# 33         000000000006                                  1
# 903        000000000020                                  1
# 216        000000000158                                  1
#
#       NRO_DE_IDENTIFICACION_DEL_TITULAR INDICADOR_DE_SOLO_TITULAR_PRINCIPAL  \
# 856                     000000000119525                                   T
# 857                     000000000119525                                   T
# ...

# %%
df_embargos = pd.read_csv("data/input/embargos.csv", sep=",", header=0, index_col = False, dtype=str)

# %%
display(df_embargos)
# Out:
#     ACCOUNTOFFICE ALLOCATIONDATE APPLICATIONDATE BANKCODE       BANKNAME  \
# 0             918            NaN             NaN       40    Banco Todos
# 1             918            NaN             NaN       40    Banco Todos
# 2             918            NaN             NaN       40    Banco Todos
# 3             918            NaN             NaN       40    Banco Todos
# 4             918            NaN             NaN       40    Banco Todos
# ..            ...            ...             ...      ...            ...
# 860           918            NaN             NaN       40            NaN
# 861           918            NaN             NaN       40  Banco Agrario
# 862           918            NaN             NaN       40  Banco Agrario
# 863           918            NaN             NaN       40  Banco Agrario
# 864           918            NaN             NaN       40            NaN
#
#                         CASEREFERENCE CHECKCD CHEKMASIVO         CITY  \
# ...

# %%
df_embargos[["RESPONDENTID"]]
# Out:
#        RESPONDENTID
# 0         890900250
# 1          59152459
# 2    19091109214037
# 3         219030612
# 4        5059152464
# ..              ...
# 860        13871433
# 861        13007905
# 862       900549488
# 863        74811641
# 864        91295189
#
# [865 rows x 1 columns]

# %%
df_embargos.describe()
# Out:
#        ACCOUNTOFFICE ALLOCATIONDATE APPLICATIONDATE BANKCODE     BANKNAME  \
# count            865              0               0      801          654
# unique             1              0               0        2            5
# top              918            NaN             NaN       40  Banco Todos
# freq             865            NaN             NaN      800          345
#
#                            CASEREFERENCE CHECKCD CHEKMASIVO      CITY  \
# count                                865     865        865       865
# unique                               379       1          2        91
# top     B1A02109A2BA11EB815800155D321E71      NO         NO  BARRANCA
# freq                                 281     865        850       281
#
#        CLAIMANTENTITY  ... RESPONDENTID          RESPONDENTNAME  \
# count             688  ...          858                     857
# unique             17  ...          748                     772
# ...

# %%
df_embargos.shape
# Out:
# (865, 51)

# %%
df_embargos.dtypes
# Out:
# ACCOUNTOFFICE       object
# ALLOCATIONDATE      object
# APPLICATIONDATE     object
# BANKCODE            object
# BANKNAME            object
# CASEREFERENCE       object
# CHECKCD             object
# CHEKMASIVO          object
# CITY                object
# CLAIMANTENTITY      object
# CLAIMANTID          object
# CLAIMANTNAME        object
# CLIENTSEGMENT       object
# CLOSEDOPEN          object
# COMPLEJIDAD         object
# DOCTYPE             object
# EMISSIONDATE        object
# EMPLOYEENAME        object
# ENTITYPROCESS       object
# ENTRYCHANNEL        object
# FILEDID             object
# FILIALID            object
# FUTURE              object
# HASRETURNED         object
# ISLINKED            object
# ISTOWAITFORGUID     object
# LAWTYPE             object
# LEGALADDRESS        object
# LEGALDEPARTMENT     object
# LEGALNAME           object
# LEGALNUMBER         object
# LETTERTYPE          object
# MANAGEOBS           object
# ORACLEID            object
# ...

# %%
total_nulos = df_embargos.isnull().sum().sort_values(ascending = False)
porcentaje_nulos = (df_embargos.isnull().sum()/df_embargos.isnull().count()).sort_values(ascending = False)
cuadro_nulos = pd.concat([total_nulos, porcentaje_nulos], axis = 1, keys = ['total_nulos','porcentaje_nulos'])
cuadro_nulos
# Out:
#                   total_nulos  porcentaje_nulos
# APPLICATIONDATE           865          1.000000
# ALLOCATIONDATE            865          1.000000
# MANAGEOBS                 865          1.000000
# CLIENTSEGMENT             865          1.000000
# SPECIALANOTATION          865          1.000000
# SISTEMBANKNAME            865          1.000000
# SCANUSER                  653          0.754913
# CLAIMANTID                529          0.611561
# ISTOWAITFORGUID           520          0.601156
# SUBSEGMENT                518          0.598844
# ISLINKED                  347          0.401156
# LEGALNUMBER               301          0.347977
# PAIDACCOUNTNO             211          0.243931
# BANKNAME                  211          0.243931
# CLAIMANTENTITY            177          0.204624
# FILIALID                  177          0.204624
# CLAIMANTNAME              177          0.204624
# CLOSEDOPEN                177          0.204624
# EMISSIONDATE              177          0.204624
# ...

# %% [markdown]
# ### Join dataframes

# %%
df_productos[["TIPO_DE_IDENTIFICACION_DEL_TITULAR"]].dtypes
# Out:
# TIPO_DE_IDENTIFICACION_DEL_TITULAR    object
# dtype: object

# %%
df_productos[["NRO_DE_IDENTIFICACION_DEL_TITULAR"]].dtypes
# Out:
# NRO_DE_IDENTIFICACION_DEL_TITULAR    object
# dtype: object

# %%
df_embargos[["DOCTYPE"]].dtypes
# Out:
# DOCTYPE    object
# dtype: object

# %%
df_embargos[["RESPONDENTID"]].dtypes
df_embargos[["RESPONDENTID"]].head()
# Out:
#      RESPONDENTID
# 0       890900250
# 1        59152459
# 2  19091109214037
# 3       219030612
# 4      5059152464

# %% [markdown]
# ### DESTINO PRODUCTOS EMBARGADOS

# %%
df_productos.merge(df_embargos, how="left", left_on=["TIPO_DE_IDENTIFICACION_DEL_TITULAR", "NRO_DE_IDENTIFICACION_DEL_TITULAR"], right_on=["DOCTYPE", "RESPONDENTID"])
# Out:
#       NUMERO_DE_RASTREO TIPO_DE_IDENTIFICACION_DEL_TITULAR  \
# 0          000000000001                                  1
# 1          000000000021                                  1
# 2          000000000002                                  1
# 3          000000000040                                  1
# 4          000000000023                                  1
# ...                 ...                                ...
# 34205      000000000016                                  1
# 34206      000000000016                                  1
# 34207      000000000023                                  1
# 34208      000000000024                                  1
# 34209      000000000026                                  1
#
#       NRO_DE_IDENTIFICACION_DEL_TITULAR INDICADOR_DE_SOLO_TITULAR_PRINCIPAL  \
# 0                       000000068287066                                   T
# 1                       000000008699669                                   T
# ...

# %%
# %pip install mysql-connector
# Out:
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# ...
#   Using cached mysql-connector-2.2.9.tar.gz (11.9 MB)
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for mysql-connector: filename=mysql_connector-2.2.9-cp39-cp39-macosx_12_0_arm64.whl size=247956 sha256=dc083e04d64ed6dff2813ba5d113ad0d2cf89726c8b88e27160b32780c8c1f15
#   Stored in directory: /Users/jeanflores/Library/Caches/pip/wheels/7b/14/39/5aad423666e827dfe9a1fbcd111ac17171e7c9865d570780ce
# Successfully built mysql-connector
# ...
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# ...

# %% [markdown]
# Create tables

# %%
import mysql.connector

db = mysql.connector.connect(
    host="localhost",
    user="root",
    password="123456",
    database="embargos"
)

# %%
cr = db.cursor(buffered=True)

# %%
cr.execute('''
    CREATE TABLE IF NOT EXISTS embargos (
    estado varchar(4) NOT NULL,
    anotacion varchar(30) NOT NULL,
    localidad varchar(30) NOT NULL,
    complejidad varchar(50) NOT NULL,
    detalle_complejidad varchar(50) NOT NULL,
    encargado varchar(100) NOT NULL,
    fecha_recepcion varchar(10) NOT NULL,
    hora_recepcion varchar(10) NOT NULL,
    job_id varchar(20) NOT NULL,
    fecha_embargo varchar(20) NOT NULL,
    id_oracle varchar(20) NOT NULL,
    efectivo varchar(10) NOT NULL,
    tipo_documento varchar(20) NOT NULL,
    numero_documento varchar(20) NOT NULL,
    tipo_cuenta varchar(20) NOT NULL,
    numero_cuenta varchar(20) NOT NULL
    )
''')

# %%
cr.execute('''
CREATE TABLE IF NOT EXISTS productos (
    tipo_documento varchar(20) NOT NULL,
    numero_documento varchar(20) NOT NULL,
    fecha_apertura varchar(20) NOT NULL,
    estado varchar(5) NOT NULL,
    plan varchar(5) NOT NULL,
    saldo_disponible varchar(20) NOT NULL,
    cuenta_inembargable varchar(20) NOT NULL,
    nombre_completo varchar(100) NOT NULL,
    nombre_corto varchar(20) NOT NULL,
    oficina_duena varchar(20) NOT NULL,
    marcacion_cuenta varchar(20) NOT NULL,
    cuenta_embargada varchar(20) NOT NULL
    )
''')
