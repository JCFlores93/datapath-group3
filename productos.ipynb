# %%
import pandas as pd
from IPython.display import display

# %%
column_names = ["NUMERO_DE_RASTREO", "TIPO_DE_IDENTIFICACION_DEL_TITULAR", "NRO_DE_IDENTIFICACION_DEL_TITULAR", "INDICADOR_DE_SOLO_TITULAR_PRINCIPAL", "INDICADOR_DE_OMITIR_CUENTAS_CANCELADAS",
"OFICINA_DUENA_DE_LA_CUENTA", "CUENTA_PERMITE_DEBITOS_SOBREGIRO", "CUENTA_PERMITE_CREDITOS_SOBREGIRO", "MARCAS_DE_LAS_CUENTAS", "FILLER_PARA_USO_FUTURO", "CODIGO_DE_RESPUESTA","DESCRIPCION_DE_RESPUESTA",
"CONSECUTIVO_DE_CUENTAS_CONSULTADAS_POR_CLIENTE","TIPO_DE_CUENTA_A_CONSULTAR", "NUMERO_DE_CUENTA","CODIGO_DE_LA_OFICINA_DUENA_DE_LA_CUENTA", "CUENTA_PERMITE_DEBITOS", "CUENTA_PERMITE_CREDITOS", "MONEDA", 
"FECHA_DE_APERTURA_DE_LA_CUENTA", "NUMERO_DE_DIAS_DE_INACTIVIDAD_DE_LA_CUENTA", "INDICADOR_DE_CUENTA_CANCELADA", "FECHA_DE_CIERRE_DE_LA_CUENTA","NUMERO_DE_COTITULARES", "TIPO_IDENTIFICACION_TITULAR", "NRO_DE_IDENTIFICACION_TITULAR",
"NOMBRE_TITULAR_CUENTA", "RELACION_ENTRE_CLIENTE_Y_CUENTA", "REGIMEN_CUENTA_MAESTRA", "CODIGO_DE_SERVICIO","PLAZO_SOBREGIRO", "DIAS_SOBREGIRO",
"DIAS_EN_MORA_SOBREGIRO", "CLASIFICACION_CARTERA_PARA_CTAS_CORRIENTES", "SIGNO_DEL_CUPO_DE_SOBREGIRO", "VALOR_DEL_CUPO_DE_SOBREGIRO", "SIGNO_DEL_SALDO_EFECTIVO_DE_LA_CUENTA",
"SALDO_EFECTIVO_DE_LA_CUENTA", "SIGNO_DEL_SALDO_EN_CANJE_DE_LA_CUENTA", "SALDO_EN_CANJE_DE_LA_CUENTA",
"SIGNO_DEL_SALDO_DISPONIBLE_DE_LA_CUENTA", "SALDO_DISPONIBLE_DE_LA_CUENTA", "SIGNO_DEL_SALDO_DISPONIBLE_SIN_SOBREGIRO", "SALDO_DISPONIBLE_SIN_SOBREGIRO", "SIGNO_DEL_SALDO_EN_CUENTA_POR_COBRAR",
"SALDO_EN_CUENTA_POR_COBRAR", "SIGNO_DEL_SALDO_BLOQUEADO", "SALDO_BLOQUEADO", "SIGNO_DE_SALDO_EN_BOLSILLOS", "SALDO_EN_BOLSILLOS", "SIGNO_DEL_SALDO_EN_CANJE_AL_INICIO_DEL_DIA", "SALDO_EN_CANJE_AL_INICIO_DEL_DIA",
"SIGNO_DEL_SALDO_EFECTIVO_AL_INICIO_DEL_DIA", "SALDO_EFECTIVO_AL_INICIO_DEL_DIA", "SIGNO_DEL_SALDO_DE_DISPONIBLE_DEL_CUPO_DE_SOBREGIRO", "SALDO_DE_DISPONIBLE_DEL_CUPO_DE_SOBREGIRO",
"SIGNO_INTERES_NORMALES", "INTERES_NORMALES", " SIGNO_INTERES_EN_SUSPENSION", "INTERES_EN_SUSPENSION", "SIGNO_CUPO_DE_REMESAS", "CUPO_DE_REMESAS", "SIGNO_CUPO_REMESA_NEGOCIADA", "CUPO_REMESA_NEGOCIADA",
"SIGNO_UTILIZACION_REMESAS", "UTILIZACION_REMESAS", "UTILIZACION_DE_REMESAS", "PARA_USO_FUTURO_INFO_DE_LA_CUENTA", "CAPTACION"
]
# import collections
# print([item for item, count in collections.Counter(column_names).items() if count > 1])

print(len(column_names))

types = {}

for value in column_names:
    types[value] = str

df_productos_legales = pd.read_csv("data/input/ProductosLegales", sep="|", header=None, names=column_names, index_col=False, dtype=types)
display(df_productos_legales)
# Out:
# 69
# {'NUMERO_DE_RASTREO': <class 'str'>, 'TIPO_DE_IDENTIFICACION_DEL_TITULAR': <class 'str'>, 'NRO_DE_IDENTIFICACION_DEL_TITULAR': <class 'str'>, 'INDICADOR_DE_SOLO_TITULAR_PRINCIPAL': <class 'str'>, 'INDICADOR_DE_OMITIR_CUENTAS_CANCELADAS': <class 'str'>, 'OFICINA_DUENA_DE_LA_CUENTA': <class 'str'>, 'CUENTA_PERMITE_DEBITOS_SOBREGIRO': <class 'str'>, 'CUENTA_PERMITE_CREDITOS_SOBREGIRO': <class 'str'>, 'MARCAS_DE_LAS_CUENTAS': <class 'str'>, 'FILLER_PARA_USO_FUTURO': <class 'str'>, 'CODIGO_DE_RESPUESTA': <class 'str'>, 'DESCRIPCION_DE_RESPUESTA': <class 'str'>, 'CONSECUTIVO_DE_CUENTAS_CONSULTADAS_POR_CLIENTE': <class 'str'>, 'TIPO_DE_CUENTA_A_CONSULTAR': <class 'str'>, 'NUMERO_DE_CUENTA': <class 'str'>, 'CODIGO_DE_LA_OFICINA_DUENA_DE_LA_CUENTA': <class 'str'>, 'CUENTA_PERMITE_DEBITOS': <class 'str'>, 'CUENTA_PERMITE_CREDITOS': <class 'str'>, 'MONEDA': <class 'str'>, 'FECHA_DE_APERTURA_DE_LA_CUENTA': <class 'str'>, 'NUMERO_DE_DIAS_DE_INACTIVIDAD_DE_LA_CUENTA': <class 'str'>, 'INDICADOR_DE_CUENTA_CANCELADA': <class 'str'>, 'FECHA_DE_CIERRE_DE_LA_CUENTA': <class 'str'>, 'NUMERO_DE_COTITULARES': <class 'str'>, 'TIPO_IDENTIFICACION_TITULAR': <class 'str'>, 'NRO_DE_IDENTIFICACION_TITULAR': <class 'str'>, 'NOMBRE_TITULAR_CUENTA': <class 'str'>, 'RELACION_ENTRE_CLIENTE_Y_CUENTA': <class 'str'>, 'REGIMEN_CUENTA_MAESTRA': <class 'str'>, 'CODIGO_DE_SERVICIO': <class 'str'>, 'PLAZO_SOBREGIRO': <class 'str'>, 'DIAS_SOBREGIRO': <class 'str'>, 'DIAS_EN_MORA_SOBREGIRO': <class 'str'>, 'CLASIFICACION_CARTERA_PARA_CTAS_CORRIENTES': <class 'str'>, 'SIGNO_DEL_CUPO_DE_SOBREGIRO': <class 'str'>, 'VALOR_DEL_CUPO_DE_SOBREGIRO': <class 'str'>, 'SIGNO_DEL_SALDO_EFECTIVO_DE_LA_CUENTA': <class 'str'>, 'SALDO_EFECTIVO_DE_LA_CUENTA': <class 'str'>, 'SIGNO_DEL_SALDO_EN_CANJE_DE_LA_CUENTA': <class 'str'>, 'SALDO_EN_CANJE_DE_LA_CUENTA': <class 'str'>, 'SIGNO_DEL_SALDO_DISPONIBLE_DE_LA_CUENTA': <class 'str'>, 'SALDO_DISPONIBLE_DE_LA_CUENTA': <class 'str'>, 'SIGNO_DEL_SALDO_DISPONIBLE_SIN_SOBREGIRO': <class 'str'>, 'SALDO_DISPONIBLE_SIN_SOBREGIRO': <class 'str'>, 'SIGNO_DEL_SALDO_EN_CUENTA_POR_COBRAR': <class 'str'>, 'SALDO_EN_CUENTA_POR_COBRAR': <class 'str'>, 'SIGNO_DEL_SALDO_BLOQUEADO': <class 'str'>, 'SALDO_BLOQUEADO': <class 'str'>, 'SIGNO_DE_SALDO_EN_BOLSILLOS': <class 'str'>, 'SALDO_EN_BOLSILLOS': <class 'str'>, 'SIGNO_DEL_SALDO_EN_CANJE_AL_INICIO_DEL_DIA': <class 'str'>, 'SALDO_EN_CANJE_AL_INICIO_DEL_DIA': <class 'str'>, 'SIGNO_DEL_SALDO_EFECTIVO_AL_INICIO_DEL_DIA': <class 'str'>, 'SALDO_EFECTIVO_AL_INICIO_DEL_DIA': <class 'str'>, 'SIGNO_DEL_SALDO_DE_DISPONIBLE_DEL_CUPO_DE_SOBREGIRO': <class 'str'>, 'SALDO_DE_DISPONIBLE_DEL_CUPO_DE_SOBREGIRO': <class 'str'>, 'SIGNO_INTERES_NORMALES': <class 'str'>, 'INTERES_NORMALES': <class 'str'>, ' SIGNO_INTERES_EN_SUSPENSION': <class 'str'>, 'INTERES_EN_SUSPENSION': <class 'str'>, 'SIGNO_CUPO_DE_REMESAS': <class 'str'>, 'CUPO_DE_REMESAS': <class 'str'>, 'SIGNO_CUPO_REMESA_NEGOCIADA': <class 'str'>, 'CUPO_REMESA_NEGOCIADA': <class 'str'>, 'SIGNO_UTILIZACION_REMESAS': <class 'str'>, 'UTILIZACION_REMESAS': <class 'str'>, 'UTILIZACION_DE_REMESAS': <class 'str'>, 'PARA_USO_FUTURO_INFO_DE_LA_CUENTA': <class 'str'>, 'CAPTACION': <class 'str'>}
#       NUMERO_DE_RASTREO TIPO_DE_IDENTIFICACION_DEL_TITULAR  \
# 0          000000000001                                  1
# 1          000000000021                                  1
# 2          000000000002                                  1
# 3          000000000040                                  1
# 4          000000000023                                  1
# ...                 ...                                ...
# 33277      000000009025                                  1
# 33278      000000009029                                  1
# 33279      000000009030                                  1
# 33280      000000009030                                  1
# 33281      000000009030                                  1
#
#       NRO_DE_IDENTIFICACION_DEL_TITULAR INDICADOR_DE_SOLO_TITULAR_PRINCIPAL  \
# 0                       000000068287066                                   T
# 1                       000000008699669                                   T
# 2                       000001090407176                                   T
# 3                       000000080431468                                   T
# 4                       000000075070484                                   T
# ...                                 ...                                 ...
# 33277                   000000045526350                                   T
# 33278                   000000045485857                                   T
# 33279                   000001143353738                                   T
# 33280                   000001143353738                                   T
# 33281                   000001143353738                                   T
#
#       INDICADOR_DE_OMITIR_CUENTAS_CANCELADAS OFICINA_DUENA_DE_LA_CUENTA  \
# 0                                          Y                        NaN
# 1                                          Y                        NaN
# 2                                          Y                        NaN
# 3                                          Y                        NaN
# 4                                          Y                        NaN
# ...                                      ...                        ...
# 33277                                      Y                        NaN
# 33278                                      Y                        NaN
# 33279                                      Y                        NaN
# 33280                                      Y                        NaN
# 33281                                      Y                        NaN
#
#       CUENTA_PERMITE_DEBITOS_SOBREGIRO CUENTA_PERMITE_CREDITOS_SOBREGIRO  \
# 0                                  NaN                               NaN
# 1                                  NaN                               NaN
# 2                                  NaN                               NaN
# 3                                  NaN                               NaN
# 4                                  NaN                               NaN
# ...                                ...                               ...
# 33277                              NaN                               NaN
# 33278                              NaN                               NaN
# 33279                              NaN                               NaN
# 33280                              NaN                               NaN
# 33281                              NaN                               NaN
#
#       MARCAS_DE_LAS_CUENTAS FILLER_PARA_USO_FUTURO  ... INTERES_EN_SUSPENSION  \
# 0                       NaN                    NaN  ...                     +
# 1                       NaN                    NaN  ...                     +
# 2                       NaN                    NaN  ...                     +
# 3                       NaN                    NaN  ...                     +
# 4                       NaN                    NaN  ...                     +
# ...                     ...                    ...  ...                   ...
# 33277                   NaN                    NaN  ...                     +
# 33278                   NaN                    NaN  ...                     +
# 33279                   NaN                    NaN  ...                     +
# 33280                   NaN                    NaN  ...                     +
# 33281                   NaN                    NaN  ...                     +
#
#       SIGNO_CUPO_DE_REMESAS CUPO_DE_REMESAS SIGNO_CUPO_REMESA_NEGOCIADA  \
# 0      00000000000000000000               +        00000000000000000000
# 1      00000000000000000000               +        00000000000000000000
# 2      00000000000000000000               +        00000000000000000000
# 3      00000000000000000000               +        00000000000000000000
# 4      00000000000000000000               +        00000000000000000000
# ...                     ...             ...                         ...
# 33277  00000000000000000000               +        00000000000000000000
# 33278  00000000000000000000               +        00000000000000000000
# 33279  00000000000000000000               +        00000000000000000000
# 33280  00000000000000000000               +        00000000000000000000
# 33281  00000000000000000000               +        00000000000000000000
#
#       CUPO_REMESA_NEGOCIADA SIGNO_UTILIZACION_REMESAS UTILIZACION_REMESAS  \
# 0                         +      00000000000000000000                   +
# 1                         +      00000000000000000000                   +
# 2                         +      00000000000000000000                   +
# 3                         +      00000000000000000000                   +
# 4                         +      00000000000000000000                   +
# ...                     ...                       ...                 ...
# 33277                     +      00000000000000000000                   +
# 33278                     +      00000000000000000000                   +
# 33279                     +      00000000000000000000                   +
# 33280                     +      00000000000000000000                   +
# 33281                     +      00000000000000000000                   +
#
#       UTILIZACION_DE_REMESAS PARA_USO_FUTURO_INFO_DE_LA_CUENTA  \
# 0       00000000000000000000                                 +
# 1       00000000000000000000                                 +
# 2       00000000000000000000                                 +
# 3       00000000000000000000                                 +
# 4       00000000000000000000                                 +
# ...                      ...                               ...
# 33277   00000000000000000000                                 +
# 33278   00000000000000000000                                 +
# 33279   00000000000000000000                                 +
# 33280   00000000000000000000                                 +
# 33281   00000000000000000000                                 +
#
#                   CAPTACION
# 0      00000000000000000000
# 1      00000000000000000000
# 2      00000000000000000000
# 3      00000000000000000000
# 4      00000000000000000000
# ...                     ...
# 33277  00000000000000000000
# 33278  00000000000000000000
# 33279  00000000000000000000
# 33280  00000000000000000000
# 33281  00000000000000000000
#
# [33282 rows x 69 columns]

# %%
df_productos_legales.describe()
# Out:
#        NUMERO_DE_RASTREO  TIPO_DE_IDENTIFICACION_DEL_TITULAR  \
# count       33282.000000                        33282.000000
# mean        10096.942071                            2.486028
# std          3725.666340                            0.873956
# min             1.000000                            1.000000
# 25%          8259.000000                            1.000000
# 50%          9086.000000                            3.000000
# 75%         12819.500000                            3.000000
# max         18061.000000                            3.000000
#
#        NRO_DE_IDENTIFICACION_DEL_TITULAR  OFICINA_DUENA_DE_LA_CUENTA  \
# count                       3.328200e+04                         0.0
# mean                        7.605352e+08                         NaN
# std                         3.275985e+08                         NaN
# min                         2.814850e+05                         NaN
# 25%                         8.909039e+08                         NaN
# 50%                         8.909039e+08                         NaN
# 75%                         8.909039e+08                         NaN
# max                         1.235244e+09                         NaN
#
#        CUENTA_PERMITE_DEBITOS_SOBREGIRO  CUENTA_PERMITE_CREDITOS_SOBREGIRO  \
# count                               0.0                                0.0
# mean                                NaN                                NaN
# std                                 NaN                                NaN
# min                                 NaN                                NaN
# 25%                                 NaN                                NaN
# 50%                                 NaN                                NaN
# 75%                                 NaN                                NaN
# max                                 NaN                                NaN
#
#        MARCAS_DE_LAS_CUENTAS  FILLER_PARA_USO_FUTURO  \
# count                    0.0                     0.0
# mean                     NaN                     NaN
# std                      NaN                     NaN
# min                      NaN                     NaN
# 25%                      NaN                     NaN
# 50%                      NaN                     NaN
# 75%                      NaN                     NaN
# max                      NaN                     NaN
#
#        CONSECUTIVO_DE_CUENTAS_CONSULTADAS_POR_CLIENTE  NUMERO_DE_CUENTA  ...  \
# count                                    33282.000000      3.328200e+04  ...
# mean                                       306.944324      4.297144e+10  ...
# std                                        306.410109      2.947636e+10  ...
# min                                          1.000000      1.000000e+08  ...
# 25%                                          2.000000      1.530000e+10  ...
# 50%                                        228.000000      4.120000e+10  ...
# 75%                                        575.000000      6.810000e+10  ...
# max                                        921.000000      9.979012e+10  ...
#
#        SIGNO_DEL_SALDO_EN_CANJE_AL_INICIO_DEL_DIA  \
# count                                3.328200e+04
# mean                                 2.746507e+07
# std                                  1.363100e+09
# min                                  0.000000e+00
# 25%                                  0.000000e+00
# 50%                                  0.000000e+00
# 75%                                  0.000000e+00
# max                                  1.260002e+11
#
#        SIGNO_DEL_SALDO_EFECTIVO_AL_INICIO_DEL_DIA  \
# count                                3.328200e+04
# mean                                 1.123233e+09
# std                                  4.726736e+10
# min                                  0.000000e+00
# 25%                                  0.000000e+00
# 50%                                  0.000000e+00
# 75%                                  0.000000e+00
# max                                  5.936188e+12
#
#        SIGNO_DEL_SALDO_DE_DISPONIBLE_DEL_CUPO_DE_SOBREGIRO  \
# count                                       3.328200e+04
# mean                                        9.983197e+11
# std                                         4.229484e+13
# min                                         0.000000e+00
# 25%                                         0.000000e+00
# 50%                                         0.000000e+00
# 75%                                         1.000000e+04
# max                                         6.033467e+15
#
#        SIGNO_INTERES_NORMALES   SIGNO_INTERES_EN_SUSPENSION  \
# count            3.328200e+04                  3.328200e+04
# mean             1.448018e+11                  1.448018e+11
# std              8.298614e+12                  8.298614e+12
# min              0.000000e+00                  0.000000e+00
# 25%              0.000000e+00                  0.000000e+00
# 50%              0.000000e+00                  0.000000e+00
# 75%              0.000000e+00                  0.000000e+00
# max              9.400000e+14                  9.400000e+14
#
#        SIGNO_CUPO_DE_REMESAS  SIGNO_CUPO_REMESA_NEGOCIADA  \
# count           3.328200e+04                 3.328200e+04
# mean            8.345137e+06                 2.976095e+07
# std             4.814788e+08                 3.692825e+09
# min             0.000000e+00                 0.000000e+00
# 25%             0.000000e+00                 0.000000e+00
# 50%             0.000000e+00                 0.000000e+00
# 75%             0.000000e+00                 0.000000e+00
# max             4.828117e+10                 4.760949e+11
#
#        SIGNO_UTILIZACION_REMESAS  UTILIZACION_DE_REMESAS     CAPTACION
# count               3.328200e+04            3.328200e+04  3.328200e+04
# mean                1.608046e+13            1.661258e+12  8.006505e+10
# std                 5.800174e+14            1.109346e+14  1.032824e+13
# min                 0.000000e+00            0.000000e+00  0.000000e+00
# 25%                 0.000000e+00            0.000000e+00  0.000000e+00
# 50%                 0.000000e+00            0.000000e+00  0.000000e+00
# 75%                 0.000000e+00            0.000000e+00  0.000000e+00
# max                 3.000000e+16            8.000000e+15  1.332362e+15
#
# [8 rows x 39 columns]

# %%
df_productos_legales.shape
# Out:
# (33282, 69)

# %%
total_null = df_productos_legales.isnull().sum().sort_values(ascending = False) # Total de nulos
percent_null = (df_productos_legales.isnull().sum()/df_productos_legales.isnull().count()).sort_values(ascending = False) #porcentaje de nulos
missing_data = pd.concat([total_null,percent_null],axis = 1,keys=['total_null','percent_null'])
missing_data
# Out:
#                                             total_null  percent_null
# OFICINA_DUENA_DE_LA_CUENTA                       33282           1.0
# CUENTA_PERMITE_DEBITOS_SOBREGIRO                 33282           1.0
# CUENTA_PERMITE_CREDITOS_SOBREGIRO                33282           1.0
# MARCAS_DE_LAS_CUENTAS                            33282           1.0
# FILLER_PARA_USO_FUTURO                           33282           1.0
# ...                                                ...           ...
# DIAS_EN_MORA_SOBREGIRO                               0           0.0
# CLASIFICACION_CARTERA_PARA_CTAS_CORRIENTES           0           0.0
# TIPO_DE_IDENTIFICACION_DEL_TITULAR                   0           0.0
# VALOR_DEL_CUPO_DE_SOBREGIRO                          0           0.0
# CAPTACION                                            0           0.0
#
# [69 rows x 2 columns]

# %%
df_productos_legales.dtypes
# Out:
# NUMERO_DE_RASTREO                          int64
# TIPO_DE_IDENTIFICACION_DEL_TITULAR         int64
# NRO_DE_IDENTIFICACION_DEL_TITULAR          int64
# INDICADOR_DE_SOLO_TITULAR_PRINCIPAL       object
# INDICADOR_DE_OMITIR_CUENTAS_CANCELADAS    object
#                                            ...
# SIGNO_UTILIZACION_REMESAS                  int64
# UTILIZACION_REMESAS                       object
# UTILIZACION_DE_REMESAS                     int64
# PARA_USO_FUTURO_INFO_DE_LA_CUENTA         object
# CAPTACION                                  int64
# Length: 69, dtype: object

# %%
df_productos_virtuales = pd.read_csv("data/input/ProductosVirtuales", sep="|", header=None, names=column_names, dtype=types)
df_productos_virtuales.head()
# Out:
#   NUMERO_DE_RASTREO TIPO_DE_IDENTIFICACION_DEL_TITULAR  \
# 0      000000000001                                  3
# 1      000000000307                                  2
# 2      000000000307                                  3
# 3      000000000205                                  7
# 4      000000000069                                  5
#
#   NRO_DE_IDENTIFICACION_DEL_TITULAR INDICADOR_DE_SOLO_TITULAR_PRINCIPAL  \
# 0                         890900250                                   T
# 1                          59152459                                   T
# 2                    19091109214037                                   T
# 3                         219030612                                   T
# 4                        5059152464                                   T
#
#   INDICADOR_DE_OMITIR_CUENTAS_CANCELADAS OFICINA_DUENA_DE_LA_CUENTA  \
# 0                                      Y                        NaN
# 1                                      Y                        NaN
# 2                                      Y                        NaN
# 3                                      Y                        NaN
# 4                                      Y                        NaN
#
#   CUENTA_PERMITE_DEBITOS_SOBREGIRO CUENTA_PERMITE_CREDITOS_SOBREGIRO  \
# 0                              NaN                               NaN
# 1                              NaN                               NaN
# 2                              NaN                               NaN
# 3                              NaN                               NaN
# 4                              NaN                               NaN
#
#   MARCAS_DE_LAS_CUENTAS FILLER_PARA_USO_FUTURO  ... INTERES_EN_SUSPENSION  \
# 0                   NaN                    NaN  ...                     +
# 1                   NaN                    NaN  ...                     +
# 2                   NaN                    NaN  ...                     +
# 3                   NaN                    NaN  ...                     +
# 4                   NaN                    NaN  ...                     +
#
#   SIGNO_CUPO_DE_REMESAS CUPO_DE_REMESAS SIGNO_CUPO_REMESA_NEGOCIADA  \
# 0  00000000000000000000               +        00000000000000000000
# 1  00000000000000000000               +        00000000000000000000
# 2  00000000000000000000               +        00000000000000000000
# 3  00000000000000000000               +        00000000000000000000
# 4  00000000000000000000               +        00000000000000000000
#
#   CUPO_REMESA_NEGOCIADA SIGNO_UTILIZACION_REMESAS UTILIZACION_REMESAS  \
# 0                     +      00000000000000000000                   +
# 1                     +      00000000000000000000                   +
# 2                     +      00000000000000000000                   +
# 3                     +      00000000000000000000                   +
# 4                     +      00000000000000000000                   +
#
#   UTILIZACION_DE_REMESAS PARA_USO_FUTURO_INFO_DE_LA_CUENTA  \
# 0   00000000000000000000                                 +
# 1   00000000000000000000                                 +
# 2   00000000000000000000                                 +
# 3   00000000000000000000                                 +
# 4   00000000000000000000                                 +
#
#               CAPTACION
# 0  00000000000000000000
# 1  00000000000000000000
# 2  00000000000000000000
# 3  00000000000000000000
# 4  00000000000000000000
#
# [5 rows x 69 columns]

# %%
total_null = df_productos_virtuales.isnull().sum().sort_values(ascending = False) # Total de nulos
percent_null = (df_productos_virtuales.isnull().sum()/df_productos_virtuales.isnull().count()).sort_values(ascending = False) #porcentaje de nulos
missing_data = pd.concat([total_null,percent_null],axis = 1,keys=['total_null','percent_null'])
missing_data
# Out:
#                                             total_null  percent_null
# OFICINA_DUENA_DE_LA_CUENTA                         928           1.0
# CUENTA_PERMITE_DEBITOS_SOBREGIRO                   928           1.0
# CUENTA_PERMITE_CREDITOS_SOBREGIRO                  928           1.0
# MARCAS_DE_LAS_CUENTAS                              928           1.0
# FILLER_PARA_USO_FUTURO                             928           1.0
# ...                                                ...           ...
# DIAS_EN_MORA_SOBREGIRO                               0           0.0
# CLASIFICACION_CARTERA_PARA_CTAS_CORRIENTES           0           0.0
# TIPO_DE_IDENTIFICACION_DEL_TITULAR                   0           0.0
# VALOR_DEL_CUPO_DE_SOBREGIRO                          0           0.0
# CAPTACION                                            0           0.0
#
# [69 rows x 2 columns]

# %%
df_productos_virtuales.dtypes
# Out:
# NUMERO_DE_RASTREO                          int64
# TIPO_DE_IDENTIFICACION_DEL_TITULAR         int64
# NRO_DE_IDENTIFICACION_DEL_TITULAR          int64
# INDICADOR_DE_SOLO_TITULAR_PRINCIPAL       object
# INDICADOR_DE_OMITIR_CUENTAS_CANCELADAS    object
#                                            ...
# SIGNO_UTILIZACION_REMESAS                  int64
# UTILIZACION_REMESAS                       object
# UTILIZACION_DE_REMESAS                     int64
# PARA_USO_FUTURO_INFO_DE_LA_CUENTA         object
# CAPTACION                                  int64
# Length: 69, dtype: object

# %%
df_productos_legales.describe()
# Out:
#        NUMERO_DE_RASTREO  TIPO_DE_IDENTIFICACION_DEL_TITULAR  \
# count       33282.000000                        33282.000000
# mean        10096.942071                            2.486028
# std          3725.666340                            0.873956
# min             1.000000                            1.000000
# 25%          8259.000000                            1.000000
# 50%          9086.000000                            3.000000
# 75%         12819.500000                            3.000000
# max         18061.000000                            3.000000
#
#        NRO_DE_IDENTIFICACION_DEL_TITULAR  OFICINA_DUENA_DE_LA_CUENTA  \
# count                       3.328200e+04                         0.0
# mean                        7.605352e+08                         NaN
# std                         3.275985e+08                         NaN
# min                         2.814850e+05                         NaN
# 25%                         8.909039e+08                         NaN
# 50%                         8.909039e+08                         NaN
# 75%                         8.909039e+08                         NaN
# max                         1.235244e+09                         NaN
#
#        CUENTA_PERMITE_DEBITOS_SOBREGIRO  CUENTA_PERMITE_CREDITOS_SOBREGIRO  \
# count                               0.0                                0.0
# mean                                NaN                                NaN
# std                                 NaN                                NaN
# min                                 NaN                                NaN
# 25%                                 NaN                                NaN
# 50%                                 NaN                                NaN
# 75%                                 NaN                                NaN
# max                                 NaN                                NaN
#
#        MARCAS_DE_LAS_CUENTAS  FILLER_PARA_USO_FUTURO  \
# count                    0.0                     0.0
# mean                     NaN                     NaN
# std                      NaN                     NaN
# min                      NaN                     NaN
# 25%                      NaN                     NaN
# 50%                      NaN                     NaN
# 75%                      NaN                     NaN
# max                      NaN                     NaN
#
#        CONSECUTIVO_DE_CUENTAS_CONSULTADAS_POR_CLIENTE  NUMERO_DE_CUENTA  ...  \
# count                                    33282.000000      3.328200e+04  ...
# mean                                       306.944324      4.297144e+10  ...
# std                                        306.410109      2.947636e+10  ...
# min                                          1.000000      1.000000e+08  ...
# 25%                                          2.000000      1.530000e+10  ...
# 50%                                        228.000000      4.120000e+10  ...
# 75%                                        575.000000      6.810000e+10  ...
# max                                        921.000000      9.979012e+10  ...
#
#        SIGNO_DEL_SALDO_EN_CANJE_AL_INICIO_DEL_DIA  \
# count                                3.328200e+04
# mean                                 2.746507e+07
# std                                  1.363100e+09
# min                                  0.000000e+00
# 25%                                  0.000000e+00
# 50%                                  0.000000e+00
# 75%                                  0.000000e+00
# max                                  1.260002e+11
#
#        SIGNO_DEL_SALDO_EFECTIVO_AL_INICIO_DEL_DIA  \
# count                                3.328200e+04
# mean                                 1.123233e+09
# std                                  4.726736e+10
# min                                  0.000000e+00
# 25%                                  0.000000e+00
# 50%                                  0.000000e+00
# 75%                                  0.000000e+00
# max                                  5.936188e+12
#
#        SIGNO_DEL_SALDO_DE_DISPONIBLE_DEL_CUPO_DE_SOBREGIRO  \
# count                                       3.328200e+04
# mean                                        9.983197e+11
# std                                         4.229484e+13
# min                                         0.000000e+00
# 25%                                         0.000000e+00
# 50%                                         0.000000e+00
# 75%                                         1.000000e+04
# max                                         6.033467e+15
#
#        SIGNO_INTERES_NORMALES   SIGNO_INTERES_EN_SUSPENSION  \
# count            3.328200e+04                  3.328200e+04
# mean             1.448018e+11                  1.448018e+11
# std              8.298614e+12                  8.298614e+12
# min              0.000000e+00                  0.000000e+00
# 25%              0.000000e+00                  0.000000e+00
# 50%              0.000000e+00                  0.000000e+00
# 75%              0.000000e+00                  0.000000e+00
# max              9.400000e+14                  9.400000e+14
#
#        SIGNO_CUPO_DE_REMESAS  SIGNO_CUPO_REMESA_NEGOCIADA  \
# count           3.328200e+04                 3.328200e+04
# mean            8.345137e+06                 2.976095e+07
# std             4.814788e+08                 3.692825e+09
# min             0.000000e+00                 0.000000e+00
# 25%             0.000000e+00                 0.000000e+00
# 50%             0.000000e+00                 0.000000e+00
# 75%             0.000000e+00                 0.000000e+00
# max             4.828117e+10                 4.760949e+11
#
#        SIGNO_UTILIZACION_REMESAS  UTILIZACION_DE_REMESAS     CAPTACION
# count               3.328200e+04            3.328200e+04  3.328200e+04
# mean                1.608046e+13            1.661258e+12  8.006505e+10
# std                 5.800174e+14            1.109346e+14  1.032824e+13
# min                 0.000000e+00            0.000000e+00  0.000000e+00
# 25%                 0.000000e+00            0.000000e+00  0.000000e+00
# 50%                 0.000000e+00            0.000000e+00  0.000000e+00
# 75%                 0.000000e+00            0.000000e+00  0.000000e+00
# max                 3.000000e+16            8.000000e+15  1.332362e+15
#
# [8 rows x 39 columns]

# %%
df_productos = df_productos_legales.append(df_productos_virtuales)
# Out:
# /var/folders/sc/_jqd0m8s5f9gqbgm5k_1twjc0000gn/T/ipykernel_13042/4251618290.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_productos = df_productos_legales.append(df_productos_virtuales)

# %%
df_productos.shape
# Out:
# (34210, 69)

# %%
df_productos.sort_values(by=['NRO_DE_IDENTIFICACION_DEL_TITULAR'])
# Out:
#        NUMERO_DE_RASTREO  TIPO_DE_IDENTIFICACION_DEL_TITULAR  \
# 857                  218                                   1
# 856                  218                                   1
# 12114              13973                                   1
# 22047              13266                                   1
# 13899              12040                                   1
# ...                  ...                                 ...
# 292                  115                                   1
# 340                  204                                   2
# 290                  249                                   1
# 872                    9                                   3
# 2                    307                                   3
#
#        NRO_DE_IDENTIFICACION_DEL_TITULAR INDICADOR_DE_SOLO_TITULAR_PRINCIPAL  \
# 857                               119525                                   T
# 856                               119525                                   T
# 12114                             281485                                   T
# 22047                             379510                                   T
# 13899                             379510                                   T
# ...                                  ...                                 ...
# 292                        1805260554145                                   T
# 340                        1805260554703                                   T
# 290                        1805260557198                                   T
# 872                       19091109214037                                   T
# 2                         19091109214037                                   T
#
#       INDICADOR_DE_OMITIR_CUENTAS_CANCELADAS  OFICINA_DUENA_DE_LA_CUENTA  \
# 857                                        Y                         NaN
# 856                                        Y                         NaN
# 12114                                      Y                         NaN
# 22047                                      Y                         NaN
# 13899                                      Y                         NaN
# ...                                      ...                         ...
# 292                                        Y                         NaN
# 340                                        Y                         NaN
# 290                                        Y                         NaN
# 872                                        Y                         NaN
# 2                                          Y                         NaN
#
#        CUENTA_PERMITE_DEBITOS_SOBREGIRO  CUENTA_PERMITE_CREDITOS_SOBREGIRO  \
# 857                                 NaN                                NaN
# 856                                 NaN                                NaN
# 12114                               NaN                                NaN
# 22047                               NaN                                NaN
# 13899                               NaN                                NaN
# ...                                 ...                                ...
# 292                                 NaN                                NaN
# 340                                 NaN                                NaN
# 290                                 NaN                                NaN
# 872                                 NaN                                NaN
# 2                                   NaN                                NaN
#
#        MARCAS_DE_LAS_CUENTAS  FILLER_PARA_USO_FUTURO  ...  \
# 857                      NaN                     NaN  ...
# 856                      NaN                     NaN  ...
# 12114                    NaN                     NaN  ...
# 22047                    NaN                     NaN  ...
# 13899                    NaN                     NaN  ...
# ...                      ...                     ...  ...
# 292                      NaN                     NaN  ...
# 340                      NaN                     NaN  ...
# 290                      NaN                     NaN  ...
# 872                      NaN                     NaN  ...
# 2                        NaN                     NaN  ...
#
#       INTERES_EN_SUSPENSION SIGNO_CUPO_DE_REMESAS  CUPO_DE_REMESAS  \
# 857                       +                     0                +
# 856                       +                     0                +
# 12114                     +                     0                +
# 22047                     +                     0                +
# 13899                     +                     0                +
# ...                     ...                   ...              ...
# 292                       +                     0                +
# 340                       +                     0                +
# 290                       +                     0                +
# 872                       +                     0                +
# 2                         +                     0                +
#
#       SIGNO_CUPO_REMESA_NEGOCIADA  CUPO_REMESA_NEGOCIADA  \
# 857                             0                      +
# 856                             0                      +
# 12114                           0                      +
# 22047                           0                      +
# 13899                           0                      +
# ...                           ...                    ...
# 292                             0                      +
# 340                             0                      +
# 290                             0                      +
# 872                             0                      +
# 2                               0                      +
#
#        SIGNO_UTILIZACION_REMESAS UTILIZACION_REMESAS UTILIZACION_DE_REMESAS  \
# 857                            0                   +                      0
# 856                            0                   +                      0
# 12114                          0                   +                      0
# 22047                          0                   +                      0
# 13899                          0                   +                      0
# ...                          ...                 ...                    ...
# 292                            0                   +                      0
# 340                            0                   +                      0
# 290                            0                   +                      0
# 872                            0                   +                      0
# 2                              0                   +                      0
#
#       PARA_USO_FUTURO_INFO_DE_LA_CUENTA  CAPTACION
# 857                                   +          0
# 856                                   +          0
# 12114                                 +          0
# 22047                                 +          0
# 13899                                 +          0
# ...                                 ...        ...
# 292                                   +          0
# 340                                   +          0
# 290                                   +          0
# 872                                   +          0
# 2                                     +          0
#
# [34210 rows x 69 columns]
